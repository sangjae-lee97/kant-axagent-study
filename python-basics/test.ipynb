# %% [markdown]
# 1번 답안
#
# 핵심 구조 파악 후 표현
#
# 2번 답안
#
# 1,2,4
#
# 3번 답안
#
# interpreter
#
# 4번 답안
#
# 1,2,4
#
# 5번 답안
#
# error
#
# 6번 답안
#
# 1,2,3,4
#
# 7번 답안
#
# python 100
#
# 8번 답안
#
# 1,2,3,5
#
# 9번 답안
#
# str
#
# 10번 답안
#
# 2,3,4,5
#
# 11번 답안
#
# 3,2
#
# 12번 답안
#
# 1,2,5
#
# 13번 답안
#
# ytho
#
# 14번 답안
#
# 1,2,3,5
#
# 15번 답안
#
# str
#
# 16번 답안
#
# 1,2,3,5
#
# 17번 답안
#
# 통과
#
# 18번 답안
#
# 1,2,4,5
#
# 19번 답안
#
# 5
#
# 20번 답안
#
# 1,2,3,5
#
# 21번 답안
#
# 리스트
#
# 22번 답안
#
# print("포도")
#
# 23번 답안
#
# 1,2,4,5
#
# 24번 답안
#
# 1,2,3,4,5
#
# 25번 답안
#
# 26번 답안
#
# 1,2,3,5
#
# 27번 답안
#
# return
#
# 28번 답안
#
# 1,3,5
#
# 29번 답안
#
# python -m venv .venv
#
# 30번 답안
#
# 1,2,3,5
#
# 31번 답안
#
# r()
#
# 32번 답안
#
# 1,2,3,5
#
# 33번 답안
#
# int 타입으로 변환 안됌(숫자로변환될수 없는 문자)
#
# 34번 답안
#
# 2,3,4
#
# 35번 답안
#
# 붕어빵틀을 이용해 만든 붕어빵
#
# 36번 답안
#
# 1,3,4
#
# 37번 답안
#
# IPO
#
# 38번 답안
#
# 1,3,5
#
# 39번 답안
#
# 코드를 정의하고 분석하고 확인하고 판단하는 능력
#
# 40번 답안
#
# 1,2,4
#
# 41번 답안
#
# python --version
#
# 42번 답안
#
# 1,3,4
#
# 43번 답안
#
# 비밀번호(.env)
#
# 44번 답안
#
# 1,2,3,5
#
# 45번 답안
#
# #
#
# 46번 답안
#
# 1,2,5
#
# 47번 답안
#
# 문자열이어서 정수 변환 안됌
#
# 48번 답안
#
# 3
#
# 49번 답안
#
# 9
#
# 50번 답안
#
# 1,2,4
#
# 51번 답안
#
# n
#
# 52번 답안
#
# 1,2,3,5
#
# 53번 답안
#
# 13
#
# 54번 답안
#
# 1,2,3,5
#
# 55번 답안
#
# B
#
# 56번 답안
#
# 1,2,4,5
#
# 57번 답안
#
# 6
#
# 58번 답안
#
# 1,2,4,5
#
# 59번 답안
#
# 1,2,3
#
# 60번 답안
#
# 1,2,3
#
# 61번 답안
#
# set=[]
#
# 62번 답안
#
# 1,2,3,5
#
# 63번 답안
#
# get()
#
# 64번 답안
#
# 1,2,3,4
#
# 65번 답안
#
# def
#
# 66번 답안
#
# 1,2,3,4
#
# 67번 답안
#
# requirements.txt
#
# 68번 답안
#
# 1,2,3,5
#
# 69번 답안
#
# append()
#
# 70번 답안
#
# 1,2,3,5
#
# 71번 답안
#
# 위치와 타입
#
# 72번 답안
#
# 1,2,3,4,5
#
# 73번 답안
#
# __init__
#
# 74번 답안
#
# 1,2,4,5
#
# 75번 답안
#
# 모듈
#
# 76번 답안
#
# 1,2,3,4

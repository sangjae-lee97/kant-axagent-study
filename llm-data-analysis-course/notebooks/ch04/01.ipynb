# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd()

# print(PROJECT_ROOT)

DATA_DIR = PROJECT_ROOT / "data" / "raw"

print(DATA_DIR)
# Out:
# c:\dev\kant-axagent-study\llm-data-analysis-course\notebooks\ch04\data\raw

# %%
# 현재 폴더를 확인한다.
current = Path.cwd().resolve()
print("현재 위치:", current)
project_root = current
# 현재 폴더 안에 data 폴더가 있는지 확인한다.
while True:
# 만약 data 폴더가 있다면
    if (current/"data").is_dir():
#     현재 폴더를 프로젝트 루트로 결정한다.
        project_root = current    
#     탐색을 종료한다.
        break

# 만약 data 폴더가 없다면
#     부모 폴더로 한 단계 올라간다.
    current = current.parent
# 다시 data 폴더가 있는지 확인한다.

# 이 과정을 반복한다.
# 더 이상 위로 올라갈 수 없는데도
# 데이터 폴더를 찾지 못했다면
# 오류를 발생시킨다.

print("프로젝트 루트 :", project_root )
# Out:
# 현재 위치: C:\dev\kant-axagent-study\llm-data-analysis-course\notebooks\ch04
# 프로젝트 루트 : C:\dev\kant-axagent-study\llm-data-analysis-course

# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent.parent
sys.path.append(str(project_root))

print(project_root)
# Out:
# c:\dev\kant-axagent-study\llm-data-analysis-course

# %%
from course_utils.paths import get_project_root, get_data_dir

print("프로젝트 루트 :", get_project_root())
print("데이터 폴더 :", get_data_dir())
# Out:
# 프로젝트 루트 : C:\dev\kant-axagent-study\llm-data-analysis-course
# 데이터 폴더 : C:\dev\kant-axagent-study\llm-data-analysis-course\data

# %%
import pandas as pd
df = pd.read_csv(get_data_dir() / "raw/customer.csv")

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   customer_id  150 non-null    int64
#  1   name         150 non-null    str
#  2   gender       150 non-null    str
#  3   age          150 non-null    int64
#  4   city         150 non-null    str
#  5   signup_date  150 non-null    str
# dtypes: int64(2), str(4)
# memory usage: 7.2 KB
